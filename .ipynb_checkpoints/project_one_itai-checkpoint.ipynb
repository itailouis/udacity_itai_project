# %% [markdown]
# # Investigate a Dataset on Medical Appointment No Shows

# %% [markdown]
# This dataset collects information
# from 100k medical appointments in
# Brazil and is focused on the question
# of whether or not patients show up
# for their appointment. A number of
# characteristics about the patient are
# included in each row.

# %% [markdown]
# > - **ScheduledDay** tells us on what day the patient set up their appointment.
# > - **Neighborhood** indicates the location of the hospital.
# > - **Scholarship** indicates whether or not the patient is enrolled in Brasilian welfare program Bolsa Família.

# %% [markdown]
# ### Import  library to be used

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
% matplotlib inline

# %% [markdown]
# ## Data Wrangling

# %%
df= pd.read_csv("dataset/appointments.csv")
df.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# 1         0           0        0             0      No
# 2         0           0        0             0      No
# 3         0           0        0             0      No
# 4         1           0        0             0      No

# %%
df.shape
# Out:
# (110527, 14)

# %%
df.columns
# Out:
# Index(['PatientId', 'AppointmentID', 'Gender', 'ScheduledDay',
#        'AppointmentDay', 'Age', 'Neighbourhood', 'Scholarship', 'Hipertension',
#        'Diabetes', 'Alcoholism', 'Handcap', 'SMS_received', 'No-show'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %% [markdown]
# > - The ScheduledDay are object not datetime
# > - The AppointmentDay are object not datetime
# > - no-show is object
# > - There are no missing values

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# PatientId      110527.0  1.474963e+14  2.560949e+14  3.921784e+04
# AppointmentID  110527.0  5.675305e+06  7.129575e+04  5.030230e+06
# Age            110527.0  3.708887e+01  2.311020e+01 -1.000000e+00
# Scholarship    110527.0  9.826558e-02  2.976748e-01  0.000000e+00
# Hipertension   110527.0  1.972459e-01  3.979213e-01  0.000000e+00
# Diabetes       110527.0  7.186479e-02  2.582651e-01  0.000000e+00
# Alcoholism     110527.0  3.039981e-02  1.716856e-01  0.000000e+00
# Handcap        110527.0  2.224796e-02  1.615427e-01  0.000000e+00
# SMS_received   110527.0  3.210256e-01  4.668727e-01  0.000000e+00
#
#                         25%           50%           75%           max
# PatientId      4.172614e+12  3.173184e+13  9.439172e+13  9.999816e+14
# AppointmentID  5.640286e+06  5.680573e+06  5.725524e+06  5.790484e+06
# Age            1.800000e+01  3.700000e+01  5.500000e+01  1.150000e+02
# Scholarship    0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# Hipertension   0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# Diabetes       0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# Alcoholism     0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# Handcap        0.000000e+00  0.000000e+00  0.000000e+00  4.000000e+00
# SMS_received   0.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00

# %%
df_corr=df.corr()
df_corr.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style type="text/css">
# #T_2334e_row0_col0, #T_2334e_row1_col1, #T_2334e_row2_col2, #T_2334e_row3_col3, #T_2334e_row4_col4, #T_2334e_row5_col5, #T_2334e_row6_col6, #T_2334e_row7_col7, #T_2334e_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2334e_row0_col1, #T_2334e_row1_col0, #T_2334e_row6_col7, #T_2334e_row7_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_2334e_row0_col2, #T_2334e_row0_col3, #T_2334e_row2_col0, #T_2334e_row3_col0, #T_2334e_row4_col8, #T_2334e_row8_col4 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_2334e_row0_col4, #T_2334e_row0_col7, #T_2334e_row0_col8, #T_2334e_row3_col7, #T_2334e_row4_col0, #T_2334e_row7_col0, #T_2334e_row7_col3, #T_2334e_row8_col0 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_2334e_row0_col5, #T_2334e_row3_col8, #T_2334e_row5_col0, #T_2334e_row8_col3 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_2334e_row0_col6, #T_2334e_row1_col4, #T_2334e_row2_col8, #T_2334e_row4_col1, #T_2334e_row6_col0, #T_2334e_row8_col2 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_2334e_row1_col2, #T_2334e_row2_col1, #T_2334e_row3_col4, #T_2334e_row4_col3 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_2334e_row1_col3, #T_2334e_row1_col5, #T_2334e_row3_col1, #T_2334e_row5_col1, #T_2334e_row5_col6, #T_2334e_row6_col5 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_2334e_row1_col6, #T_2334e_row6_col1 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_2334e_row1_col7, #T_2334e_row7_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_2334e_row1_col8, #T_2334e_row8_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_2334e_row2_col3, #T_2334e_row3_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_2334e_row2_col4, #T_2334e_row4_col2 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_2334e_row2_col5, #T_2334e_row5_col2 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_2334e_row2_col6, #T_2334e_row6_col2 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_2334e_row2_col7, #T_2334e_row4_col7, #T_2334e_row7_col2, #T_2334e_row7_col4 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_2334e_row3_col5, #T_2334e_row5_col3, #T_2334e_row7_col8, #T_2334e_row8_col7 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_2334e_row3_col6, #T_2334e_row6_col3 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_2334e_row4_col5, #T_2334e_row5_col4 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_2334e_row4_col6, #T_2334e_row6_col4 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_2334e_row5_col7, #T_2334e_row7_col5 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_2334e_row5_col8, #T_2334e_row8_col5 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_2334e_row6_col8, #T_2334e_row8_col6 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2334e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2334e_level0_col0" class="col_heading level0 col0" >PatientId</th>
#       <th id="T_2334e_level0_col1" class="col_heading level0 col1" >AppointmentID</th>
#       <th id="T_2334e_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_2334e_level0_col3" class="col_heading level0 col3" >Scholarship</th>
#       <th id="T_2334e_level0_col4" class="col_heading level0 col4" >Hipertension</th>
#       <th id="T_2334e_level0_col5" class="col_heading level0 col5" >Diabetes</th>
#       <th id="T_2334e_level0_col6" class="col_heading level0 col6" >Alcoholism</th>
#       <th id="T_2334e_level0_col7" class="col_heading level0 col7" >Handcap</th>
#       <th id="T_2334e_level0_col8" class="col_heading level0 col8" >SMS_received</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2334e_level0_row0" class="row_heading level0 row0" >PatientId</th>
#       <td id="T_2334e_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_2334e_row0_col1" class="data row0 col1" >0.004039</td>
#       <td id="T_2334e_row0_col2" class="data row0 col2" >-0.004139</td>
#       <td id="T_2334e_row0_col3" class="data row0 col3" >-0.002880</td>
#       <td id="T_2334e_row0_col4" class="data row0 col4" >-0.006441</td>
#       <td id="T_2334e_row0_col5" class="data row0 col5" >0.001605</td>
#       <td id="T_2334e_row0_col6" class="data row0 col6" >0.011011</td>
#       <td id="T_2334e_row0_col7" class="data row0 col7" >-0.007916</td>
#       <td id="T_2334e_row0_col8" class="data row0 col8" >-0.009749</td>
#     </tr>
#     <tr>
#       <th id="T_2334e_level0_row1" class="row_heading level0 row1" >AppointmentID</th>
#       <td id="T_2334e_row1_col0" class="data row1 col0" >0.004039</td>
#       <td id="T_2334e_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_2334e_row1_col2" class="data row1 col2" >-0.019126</td>
#       <td id="T_2334e_row1_col3" class="data row1 col3" >0.022615</td>
#       <td id="T_2334e_row1_col4" class="data row1 col4" >0.012752</td>
#       <td id="T_2334e_row1_col5" class="data row1 col5" >0.022628</td>
#       <td id="T_2334e_row1_col6" class="data row1 col6" >0.032944</td>
#       <td id="T_2334e_row1_col7" class="data row1 col7" >0.014106</td>
#       <td id="T_2334e_row1_col8" class="data row1 col8" >-0.256618</td>
#     </tr>
#     <tr>
#       <th id="T_2334e_level0_row2" class="row_heading level0 row2" >Age</th>
#       <td id="T_2334e_row2_col0" class="data row2 col0" >-0.004139</td>
#       <td id="T_2334e_row2_col1" class="data row2 col1" >-0.019126</td>
#       <td id="T_2334e_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_2334e_row2_col3" class="data row2 col3" >-0.092457</td>
#       <td id="T_2334e_row2_col4" class="data row2 col4" >0.504586</td>
#       <td id="T_2334e_row2_col5" class="data row2 col5" >0.292391</td>
#       <td id="T_2334e_row2_col6" class="data row2 col6" >0.095811</td>
#       <td id="T_2334e_row2_col7" class="data row2 col7" >0.078033</td>
#       <td id="T_2334e_row2_col8" class="data row2 col8" >0.012643</td>
#     </tr>
#     <tr>
#       <th id="T_2334e_level0_row3" class="row_heading level0 row3" >Scholarship</th>
#       <td id="T_2334e_row3_col0" class="data row3 col0" >-0.002880</td>
#       <td id="T_2334e_row3_col1" class="data row3 col1" >0.022615</td>
#       <td id="T_2334e_row3_col2" class="data row3 col2" >-0.092457</td>
#       <td id="T_2334e_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_2334e_row3_col4" class="data row3 col4" >-0.019729</td>
#       <td id="T_2334e_row3_col5" class="data row3 col5" >-0.024894</td>
#       <td id="T_2334e_row3_col6" class="data row3 col6" >0.035022</td>
#       <td id="T_2334e_row3_col7" class="data row3 col7" >-0.008586</td>
#       <td id="T_2334e_row3_col8" class="data row3 col8" >0.001194</td>
#     </tr>
#     <tr>
#       <th id="T_2334e_level0_row4" class="row_heading level0 row4" >Hipertension</th>
#       <td id="T_2334e_row4_col0" class="data row4 col0" >-0.006441</td>
#       <td id="T_2334e_row4_col1" class="data row4 col1" >0.012752</td>
#       <td id="T_2334e_row4_col2" class="data row4 col2" >0.504586</td>
#       <td id="T_2334e_row4_col3" class="data row4 col3" >-0.019729</td>
#       <td id="T_2334e_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_2334e_row4_col5" class="data row4 col5" >0.433086</td>
#       <td id="T_2334e_row4_col6" class="data row4 col6" >0.087971</td>
#       <td id="T_2334e_row4_col7" class="data row4 col7" >0.080083</td>
#       <td id="T_2334e_row4_col8" class="data row4 col8" >-0.006267</td>
#     </tr>
#     <tr>
#       <th id="T_2334e_level0_row5" class="row_heading level0 row5" >Diabetes</th>
#       <td id="T_2334e_row5_col0" class="data row5 col0" >0.001605</td>
#       <td id="T_2334e_row5_col1" class="data row5 col1" >0.022628</td>
#       <td id="T_2334e_row5_col2" class="data row5 col2" >0.292391</td>
#       <td id="T_2334e_row5_col3" class="data row5 col3" >-0.024894</td>
#       <td id="T_2334e_row5_col4" class="data row5 col4" >0.433086</td>
#       <td id="T_2334e_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_2334e_row5_col6" class="data row5 col6" >0.018474</td>
#       <td id="T_

# %%
df.nunique()
# Out:
# PatientId          62299
# AppointmentID     110527
# Gender                 2
# ScheduledDay      103549
# AppointmentDay        27
# Age                  104
# Neighbourhood         81
# Scholarship            2
# Hipertension           2
# Diabetes               2
# Alcoholism             2
# Handcap                5
# SMS_received           2
# No-show                2
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Conclusions

# %% [markdown]
# * Age have outliers
# * The number of females is great than males
